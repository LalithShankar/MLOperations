# %%
import pandas as pd
df["hello"] = pd.read_csv(r'C:\Users\a743661\PycharmProjects\MLOperations/12345.csv', header = 0, encoding = 'iso-8859-1')
len(df["hello"])
# Out:
# 41293

# %%
df = pd.read_csv(r'C:\Users\a743661\PycharmProjects\MLOperations\12345.csv', header = 0, encoding = 'iso-8859-1')
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df["hello"])
# Out:
# pandas.core.series.Series

# %%
df

# %%
type(df["hello"])

# %%
sentences = df["hello"].tolist()

# %%
sentences
# Out:
# ['60172277822',
#  'kb0011729',
#  'mobil',
#  'mobileiron',
#  'mobileiron',
#  'mobileiron',
#  'mobileiron unable',
#  'mobileiron unable receive after',
#  'mobileiron unable receive after',
#  'mobileiron unable receive after',
#  'mobileiron unable receive after registr',
#  'valid certificates avail',
#  'connection server',
#  'connection server',
#  'mobileiron connection server',
#  'cisco anyconnect valid certif',
#  'cisco anyconnect valid certificates available authent',
#  'timecard',
#  '60172277822',
#  'alert instance plwsw varyon_plwsw internal error detected',
#  'alert instance plwsw varyon_plwsw internal error detected',
#  'diskspace logicaldisk monitor burw067p',
#  'burw067p',
#  'burw067p',
#  'burw067p',
#  'burw067p values exceeded threshold space mbytes',
#  'window',
#  'windows',
#  'windows update',
#  'windows update error message',
#  'windows update error message',
#  'windows update error message windows',
# ...

# %%
sentences1 = []
for i in sentences:
    i=i.encode("ascii", "ignore")
    i=i.decode()
    sentences1.append(i)

# %%
sentences1
# Out:
# ['60172277822',
#  'kb0011729',
#  'mobil',
#  'mobileiron',
#  'mobileiron',
#  'mobileiron',
#  'mobileiron unable',
#  'mobileiron unable receive after',
#  'mobileiron unable receive after',
#  'mobileiron unable receive after',
#  'mobileiron unable receive after registr',
#  'valid certificates avail',
#  'connection server',
#  'connection server',
#  'mobileiron connection server',
#  'cisco anyconnect valid certif',
#  'cisco anyconnect valid certificates available authent',
#  'timecard',
#  '60172277822',
#  'alert instance plwsw varyon_plwsw internal error detected',
#  'alert instance plwsw varyon_plwsw internal error detected',
#  'diskspace logicaldisk monitor burw067p',
#  'burw067p',
#  'burw067p',
#  'burw067p',
#  'burw067p values exceeded threshold space mbytes',
#  'window',
#  'windows',
#  'windows update',
#  'windows update error message',
#  'windows update error message',
#  'windows update error message windows',
# ...
