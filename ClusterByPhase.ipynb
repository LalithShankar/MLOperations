# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\a743661\PycharmProjects\MLOperations\text_search3.csv', header=0, encoding='iso-8859-1')

# %%
df.head()
# Out:
#                     without_null                           stop_word  \
# 0  F5   Unable to connect to VPN  ['f5', 'unable', 'connect', 'vpn']
# 1                    60172277822                     ['60172277822']
# 2                      KB0011729                       ['kb0011729']
# 3                             Mo                              ['mo']
# 4                         Mobile                          ['mobile']
#
#                         stemming                        lemming
# 0  f5   unable to connect to vpn  F5   Unable to connect to VPN
# 1                    60172277822                    60172277822
# 2                      kb0011729                      KB0011729
# 3                             Mo                             Mo
# 4                          mobil                         Mobile

# %%
x=df.stemming.tolist()

# %%
type(x)
# Out:
# list

# %%
x.to_string()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-3de49396793e> in <module>
# ----> 1 x.to_string()
#
# AttributeError: 'list' object has no attribute 'to_string'

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import numpy as np

# %%
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(x)

# %%
# Out:
# <49972x13622 sparse matrix of type '<class 'numpy.float64'>'
# 	with 161046 stored elements in Compressed Sparse Row format>

# %%
true_k = 20
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
model.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=100,
#        n_clusters=20, n_init=1, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()

# %%
for i in range(true_k):
    print("Cluster %d:" % i),
    for ind in order_centroids[i, :10]:
         print("%s" % terms[ind])
# Out:
# Cluster 0:
# set
# mfa
# mobileiron
# iphone
# vpn
# outlook
# cisco
# print
# ms
# default
# Cluster 1:
# crm
# outlook
# dynamics
# win10
# load
# add
# install
# failed
# unable
# access
# Cluster 2:
# book
# room
# outlook
# instal
# unable
# timesheet
# missing
# meeting
# install
# tool
# Cluster 3:
# laptop
# user
# slow
# wtw
# win
# unable
# screen
# win10
# loan
# wifi
# Cluster 4:
# rsa
# token
# exemption
# expired
# request
# mfa
# citrix
# login
# unable
# expir
# Cluster 5:
# microsoft
# outlook
# unable
# project
# office
# freezing
# mailbox
# affect
# stuck
# email
# Cluster 6:
# ad
# password
# reset
# account
# request
# locked
# lockout
# lock
# unlock
# security
# Cluster 7:
# mobileiron
# active
# directory
# citrix
# password
# request
# mobile
# account
# cisco
# email
# Cluster 8:
# user
# dependency
# needs
# issue
# end
# able
# unable
# pc
# login
# account
# Cluster 9:
# network
# drive
# connect
# dr
# connection
# access
# unable
# wireless
# slow
# internet
# Cluster 10:
# access
# unable
# remote
# request
# citrix
# oracle
# shared
# drive
# mailbox
# tct
# Cluster 11:
# unable
# connect
# login
# vpn
# open
# cisco
# f5
# citrix
# anyconnect
# log
# Cluster 12:
# skype
# business
# calls
# busi
# hold
# meeting
# unable
# pin
# outlook
# setup
# Cluster 13:
# windows
# 10
# low
# disk
# admin
# request
# win
# spac
# upgrade
# temporary
# Cluster 14:
# mfa
# cisco
# setup
# vpn
# unable
# anyconnect
# login
# win10
# f5
# registration
# Cluster 15:
# registrat
# mfa
# mobileiron
# mfe
# self
# iron
# mobile
# emailing
# emailno
# emailpassword
# Cluster 16:
# work
# home
# mobile
# login
# unable
# stopped
# doesn
# user
# mobileiron
# phone
# Cluster 17:
# outlook
# ms
# email
# working
# slow
# mailbox
# unable
# extremely
# open
# missing
# Cluster 18:
# win10
# outlook
# unable
# cisco
# f5
# admin
# password
# login
# vpn
# missing
# Cluster 19:
# directori
# active
# account
# talent
# home
# win10
# directory
# embed
# eme
# embde
