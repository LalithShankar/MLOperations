# %%
import spacy

# %%
spacy.load('en')

# %%
from spacy.lang.en import English
parser = English()

# %%
def tokenize(text):
    lda_tokens = []
    tokens = parser(text)
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            lda_tokens.append('URL')
        elif token.orth_.startswith('@'):
            lda_tokens.append('SCREEN_NAME')
        else:
            lda_tokens.append(token.lower_)
    return lda_tokens

# %%
import nltk
# nltk.download('wordnet')
from nltk.corpus import wordnet as wn
def get_lemma(word):
    lemma = wn.morphy(word)
    if lemma is None:
        return word
    else:
        return lemma
    
from nltk.stem.wordnet import WordNetLemmatizer
def get_lemma2(word):
    return WordNetLemmatizer().lemmatize(word)

# %%
# nltk.download('stopwords')
en_stop = set(nltk.corpus.stopwords.words('english'))

# %%
def prepare_text_for_lda(text):
    tokens = tokenize(text)
    tokens = [token for token in tokens if len(token) > 4]
    tokens = [token for token in tokens if token not in en_stop]
    tokens = [get_lemma(token) for token in tokens]
    return tokens

# %%
import random
text_data = []
with open(r'C:\Users\a743661\PycharmProjects\MLOperations/12345.csv', encoding='iso-8859-1') as f:
    for line in f:
        tokens = prepare_text_for_lda(line)
        if random.random() > .99:
            print(tokens)
            text_data.append(tokens)
# Out:
# ['disconnect', 'vcent']
# ['recover']
# ['prelogin', 'verification']
# ['carrie']
# ['adapter']
# ['win10', 'cisco', 'anyconnect', 'fail']
# ['file', 'inside', 'shortcut', 'folder', 'error', 'message']
# ['active', 'directory', 'password', 'reset']
# ['usnsh', 'db971']
# ['claim_man_mastefailed']
# ['ghost']
# ['chg0069518']
# ['refer']
# ['active', 'directori']
# ['outlook']
# ['techcentral', 'london', 'street', 'laptop', '1hyzq']
# ['september', 'compliance', 'restore', 'munich', 'segment', 'corporate', 'informatio']
# ['duplicate', 'entry', 'inc1034656']
# ['travlr']
# ['laptop']
# ['christoph', 'landvogt']
# ['microsoft', 'office', 'nepali', 'preeti', 'installation', 'concern']
# ['server', 'scope', 'percentage', 'available', 'address', 'iedbn', 'willi']
# ['win10', 'software', 'center', 'working']
# ['unmanaged', 'unowned', 'folder', 'plwsw', 'fs101']
# ['active', 'directory', 'password', 'reset']
# ['active', 'directory', 'unlock', 'lock', 'account']
# ['adapter']
# ['temporary', 'admin', 'password', 'request', 'softwar']
# ['resource', 'scheduler']
# ['windows', 'transfer', 'file']
# ['career', 'level']
# ['microsoft', 'outlook']
# ['oracle', 'unable', 'frmservlet']
# ['optica']
# ['laptop', 'performance']
# ['skype', 'business', 'request']
# ['mccann']
# ['passwo']
# ['pennsys', 'getting', 'report', 'error']
# ['oracle', 'runtime', 'environment', 'removal', 'begin', 'september']
# ['oracle', 'runtime', 'environment', 'removal', 'begin', 'september']
# ['mobileiron', 'email', 'calendar', 'access']
# ['issue', 'mobileiron', 'update']
# ['enterprise', 'vault', 'unable', 'share', 'mailbox']
# ['syntbots', 'automation', 'employee', 'transfer', 'folder', 'movement', 'sctask0604254']
# ['access']
# ['duplicate', 'ticket', 'ticket', 'inc1032150', 'problem', 'mobile', 'mobile', 'devic']
# ['aptop']
# ['outlook', 'access', 'share', 'mailbox']
# ['mcdermott']
# ['skype', 'unable', 'answer', 'call']
# ['rsspwb']
# ['check', 'video', 'confernece']
# ['mssql', 'discovery', 'fail', 'inmum', 'willis']
# ['office', 'tool', 'available', 'software']
# ['portal']
# ['databas']
# ['outlook']
# ['unable', 'launch', 'office']
# ['china']
# ['software', 'party', 'installation', 'sogou', 'softwar']
# ['laptop']
# ['compaã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83', 'ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x82', 'ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83', 'ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x82']
# ['audio', 'issue', 'vallabhi']
# ['microsoft', 'project']
# ['microsoft', 'outlook']
# ['windows', 'multiple']
# ['ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83', 'ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x82', 'ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83', 'ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x82', 'frã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83', 'ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x82', 'ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83', 'ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x82', 'kjell', 'norling', 'roland', 'rasmussen']
# ['iphon']
# ['wibshop1', 'fail']
# ['recur']
# ['broking', 'platform', 'placement', 'insured', 'failure']
# ['starting', 'block']
# ['cisco', 'anyconnect']
# ['gbips']
# ['studio']
# ['eclipse', 'unable']
# ['unable', 'access', 'share']
# ['wenke', 'amelang', 'wiesbaden', 'enterprise', 'vault', 'available']
# ['machine']
# ['unable', 'drive']
# ['chriselle', 'cardoz']
# ['inc1036314']
# ['addin']
# ['login', 'details', 'tulsi']
# ['http', 'payadvicedirect']
# ['citrix', 'unable', 'access']
# ['outlook']
# ['password']
# ['outlook', 'login']
# ['http', 'willistowerswatson', 'service']
# ['wireless']
# ['microsoft', 'outlook', 'connect']
# ['outlook', 'unable', 'access', 'share']
# ['enterprise', 'enablement', 'cisco', 'anyconnect']
# ['cyber']
# ['cyber']
# ['apply']
# ['caution', 'extern']
# ['account', 'lock']
# ['datenbank', 'recovery', 'request']
# ['total', 'utilization', 'percentage', 'microsoft', 'windows', 'server', 'standard', 'evarc']
# ['keyboard', 'issue']
# ['password', 'reset', 'request']
# ['win10', 'benefit', 'connect', 'respond']
# ['fabrizio', 'lieggi']
# ['showing', 'onmonitor']
# ['intellidox', 'unable']
# ['network', 'drive', 'miss']
# ['microsoft', 'outlook']
# ['authentication', 'problem']
# ['management', 'studio']
# ['1360704']
# ['outlook']
# ['microsoft', 'outlook']
# ['multif']
# ['cisco']
# ['complete']
# ['outlook', 'excel', 'freez']
# ['julian']
# ['wipe', 'profile']
# ['remove', 'loaner', 'profi']
# ['error', 'try']
# ['unable', 'access', 'contact']
# ['excel']
# ['dependency', 'production']
# ['skype', 'unable', 'present', 'screen']
# ['access']
# ['security', 'suspect', 'phisin']
# ['windows', 'stick']
# ['printer', 'instal']
# ['getting', 'laptop', 'upgrade', 'tonight']
# ['change', 'email', 'address', 'change', '79217']
# ['sccmo']
# ['getting', 'refern']
# ['locate', 'close', 'service']
# ['wireless']
# ['opening']
# ['loaner', 'laptop']
# ['headset', 'cisco', 'communicator', 'computer', 'working', 'properli']
# ['global', 'scape']
# ['hello', 'create', 'microsoft', 'team', 'option']
# ['outlook']
# ['outlook']
# ['duplicate', 'ticket', 'inc1037586']
# ['login', 'cisco', 'anyconnecdt']
# ['nsnm001p']
# ['win10', 'install']
# ['application', 'portfolio', 'group']
# ['kb00117']
# ['reinstall', 'mobileiron', 'update']
# ['win10']
# ['james', 'buckl']
# ['mobileiron']
# ['inter']
# ['globalscape', 'receive', 'securefile', 'transfer']
# ['martha', 'obregon', 'puede', 'acceder', 'correo', 'utilizando']
# ['outlook', 'unable', 'access', 'mail', 'vault']
# ['setup']
# ['activ']
# ['increas']
# ['password']
# ['three', 'strick']
# ['mobileiron', 'assistance', 'register', 'device', 'endorsement', 'follow', 'tomorrow']
# ['program', 'working', 'scinapt']
# ['win10', 'outlook', 'application']
# ['dependency', 'macro', 'inwh0jn542']
# ['isobel', 'huang']
# ['kb0013073', 'three', 'strike', 'process', 'latest']
# ['win10', 'indesign', 'crash']
# ['career']
# ['request']
# ['right', 'button']
# ['outlook', 'accidentally', 'email', 'wrong', 'recipi']
# ['internet', 'unable', 'access', 'extern']
# ['eclipse', 'unable']
# ['windows', 'build']
# ['token']
# ['citrix']
# ['karen', 'delaney']
# ['pms6000']
# ['laptop']
# ['win10']
# ['printer']
# ['printer', 'installation', 'request']
# ['qdb990u']
# ['inc1037765']
# ['outlook', 'toolbar', 'plugin', 'miss', 'outlook']
# ['fxact']
# ['unable', 'instal']
# ['microsoft', 'outlook', 'unable', 'shanghai', 'facility', 'services', 'willistowerswatson']
# ['windows', 'secur']
# ['payrol', 'query', 'request', 'continu']
# ['connect', 'access', 'desktop', 'current']
# ['docking', 'station', 'replace']
# ['working', '7678011217']
# ['citrix', 'account']
# ['camera']
# ['outlook']
# ['svcmgr', 'inform']
# ['access', 'benefit', 'communications']
# ['office']
# ['transf']
# ['mobil']
# ['outlook', 'prompt']
# ['outlook', 'working', 'proper', 'every', 'minit', 'later']
# ['right']
# ['legacy', 'browser', 'support']
# ['unable']
# ['check_mk', 'ap14s', 'cta2ts025']
# ['active', 'directori']
# ['kollect']
# ['call', 'velocity', 'mobile', 'hotspot']
# ['mobileiron']
# ['dev4link', 'auditlog', 'dbnot', 'getting', 'popul']
# ['error', 'messag']
# ['hardware', 'recognize', 'need']
# ['adjustmentreport_withtypeofservice', 'report']
# ['error', 'gestmat']
# ['active', 'directory']
# ['request', 'remote', 'access', 'system']
# ['dyamo', 'label', 'maker', 'application']
# ['application', 'installation', 'benefit']
# ['microsoft', 'outlook']
# ['mobileiron', 'setup']
# ['enterprise', 'vault', 'archieved', 'email']
# ['account', 'lock']
# ['software', 'token', 'access', 'inquiri']
# ['duplicate', 'ticket', 'ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83', 'ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x82', 'ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83', 'ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x82', 'inc1040418']
# ['willplace', 'superlite', 'replication', 'server']
# ['remotel']
# ['uniflow', 'print']
# ['win10']
# ['intellidox', 'avail']
# ['outlook']
# ['hyperion']
# ['outlook']
# ['windows', 'multipl']
# ['win10', 'access', 'unable', 'databas']
# ['stbk001p']
# ['laptop', 'reimage']
# ['service', 'unable', 'attach']
# ['mobileiron', 'setup']
# ['recog']
# ['active', 'directory', 'password', 'reset']
# ['unable', 'connect']
# ['disonnect']
# ['prb001580']
# ['windows10']
# ['corporate', 'launcher', 'access']
# ['apple', 'password', 'queri']
# ['mobileiron']
# ['excel']
# ['logic', 'ticket', 'error']
# ['logic', 'ticket']
# ['phone', 'working']
# ['share', 'mailbox']
# ['remote', 'desktop', 'connection', 'internal', 'error', 'occur']
# ['inc104']
# ['win10', 'visio', 'standard', 'stick']
# ['general', 'inquiry', 'follow', 'inc1028041']
# ['phone', 'showing', 'willis', 'tower', 'watson']
# ['allow']
# ['respond', 'document']
# ['dependencybattery']
# ['depsta']
# ['mobile', 'devic']
# ['mobil']
# ['recent', 'mobil', 'upgrade', 'request', 'apply', 'colleague', 'using', 'issue', 'device']
# ['configure', 'authentictor', 'devic']
# ['outlook']
# ['mobile']
# ['sctask0617858']
# ['repair']
# ['gener']
# ['inc1032178']
# ['sharepoint', 'limit']
# ['win10', 'unable', 'login']
# ['registration']
# ['monitor', 'cable']
# ['cisco', 'unable', 'connect']
# ['microsoft', 'office', 'unable', 'launch', 'rebuild', 'reprofil']
# ['project', 'librari']
# ['total', 'utilization', 'percentage', 'microsoft', 'windows', 'server', 'enterprise']
# ['registration']
# ['unable', 'package', 'xchanging']
# ['license', 'exceed']
# ['megan']
# ['premium', 'amount', 'delete', 'pending', 'transaction', 'deduction', 'tax', 'change', 'endors']
# ['transfer', 'unbale', 'mainframeservices', 'willis']
# ['volunteer']
# ['mailbox', 'personal', 'secondary', 'team', 'primari']
# ['windows']
# ['gatekeep']
# ['laptop']
# ['outlook']
# ['oracl']
# ['oracle']
# ['share', 'drive', 'unable', 'access']
# ['eclipse', 'carrier', 'receiv']
# ['email']
# ['vendor']
# ['associate', 'veronika', 'frino', 'internet', 'intranet', 'problem', 'internet', 'access', 'access', 'intranet']
# ['wrong', 'configuration']
# ['outlook', 'management', 'install']
# ['sctask0623638']
# ['bierney']
# ['unable']
# ['floor']
# ['inc1017024']
# ['win10', 'unable', 'file']
# ['mobile']
# ['paterni']
# ['talent']
# ['usnsh', 'rs333']
# ['setup']
# ['microsoft', 'outlook']
# ['ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83', 'ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x82', 'ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83', 'ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82', 'bias006d', 'internal', 'towerswatson']
# ['migration']
# ['plantronics']
# ['windows', 'unable']
# ['drive']
# ['unlock', 'error']
# ['unlock', 'error', 'logininto']
# ['concern', 'notebook', 'win10', 'j1kllq2', 'please', 'change', 'outlook', 'online', 'microsoft']
# ['login']
# ['win10', 'laptop', 'change', 'display', 'setting', 'extend']
# ['mobile', 'ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83', 'ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x82', 'ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83', 'ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x82', 'upgrade']
# ['daily', 'reprocess', 'chang']
# ['skype', 'skype', 'call', 'immediately', '30cst']
# ['16158723000']
# ['inc1020686']
# ['access', 'natct', 'internal', 'towerswatson', 'default', 'change']
# ['unable', 'install', 'amyuni', 'f7gn542']
# ['cisco', 'anyconnect', 'unable', 'login']
# ['16158723000inc1037004']
# ['webex']
# ['duplicate', 'ticket', 'ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83', 'ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x82', 'ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83', 'ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x82', 'ticket']
# ['secondary', 'monitor', 'working']
# ['corner', 'stone', 'workinf']
# ['expertise', 'access']
# ['board']
# ['barcode']
# ['laptop', 'docking', 'laptop', 'application', 'close', 'despite']
# ['enterprise', 'vault']
# ['account', 'inquiry', 'reference', 'ticket']
# ['win10', 'eclipse', 'access']
# ['general', 'question', 'advice', 'leaver']
# ['sarah', 'kutza']
# ['associa']
# ['windows', 'skype', 'respond', 'screen']
# ['ucode', 'conduct', 'train']
# ['network', 'network', 'performance', 'conflict', 'connectivity', 'issue']
# ['service', 'central', 'unable', 'access', 'approve', 'request']
# ['certificate', 'demand', 'unable', 'access', 'links']
# ['mobileunable', 'login', 'skype']
# ['system', 'center', 'management', 'health', 'service', 'authentication', 'certificate', 'expir']
# ['laptop', 'restart']
# ['network', 'network', 'performance', 'conflict', 'connectivity', 'issue', 'pacific']
# ['password']
# ['network']
# ['win10']
# ['unable', 'connect']
# ['unable', 'outlook', 'user', 'affect']
# ['julian']
# ['receive', 'email']
# ['remot']
# ['general']
# ['outlook']
# ['outlook', 'share', 'mailbox', 'connect']
# ['need', 'microsoft', 'suite']
# ['mobileiron', 'unable', 'register']
# ['benefitsmarketplac']
# ['willis', 'academy', 'access']
# ['mobileiron']
# ['foxit', 'software', 'unable', 'download']
# ['distri']
# ['network', 'connectivity', 'fail', 'ethernet', 'wireless']
# ['unable', 'connect', 'inc1038629']
# ['device', 'alarm', 'critical', 'agent']
# ['drawing', 'power', 'batteri']
# ['program', 'encounter']
# ['cisco']
# ['recover', 'delete']
# ['unable', 'client']
# ['willis_b']
# ['fail', 'connection', 'timeout']
# ['engineer', 'dependency', 'unable', 'print']
# ['working', 'properly', 'install']
# ['unable', 'access', 'clearwell']
# ['7903866800']
# ['outlook', 'delivery', 'delay', 'recipeint']
# ['share', 'mailbox']
# ['maria', 'falkn']
# ['email', 'delivery', 'issue', 'delivery', 'delay']
# ['email', 'delivery']
# ['hrc0739514']
# ['passw']
# ['macro', 'disabled', 'prompt']
# ['function', 'printer']
# ['urgent']
# ['urgent', 'submiss']
# ['email']
# ['reset', 'insurance', 'portal', 'password']
# ['svc_finmarclms_q']
# ['inc1040536']
# ['skype']
# ['skype', 'unable']
# ['loaner', 'laptop', 'unable', 'login']
# ['unable', 'connect']
# ['skype']
# ['skype']
# ['drive', 'access']
# ['vmware', 'connection', 'server', 'virtual', 'center', 'connectivity', 'break', 'connection', 'server', 'servi']
# ['email']
# ['skype', 'headset']
# ['submit', 'timecard']
# ['server', 'gbips', 'dw3016', 'slowness']
# ['outlook', 'email']
# ['ireland']
# ['employee']
# ['outlook', 'email']
# ['hdmi2', 'cable', 'meeting', 'rooms', 'nã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83', 'ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x82', 'ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83', 'ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x82', 'rumberlin', 'london']
# ['hello', 'lock', 'apply', 'wonder', 'someone']
# ['permission', 'toutlook', 'subject', 'email', 'conferenc']

# %%
type(text_data)
# Out:
# list

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\a743661\PycharmProjects\MLOperations/12345.csv', encoding='iso-8859-1')
for line in df:
        tokens = prepare_text_for_lda(line)
        if random.random() > .99:
            print(tokens)
            text_data.append(tokens)

# %%
for line in df:
    
    tokens = prepare_text_for_lda(line)
    if random.random() > .99:
        print(tokens)
        text_data.append(tokens)

# %%
from gensim import corpora
dictionary = corpora.Dictionary(text_data)
corpus = [dictionary.doc2bow(text) for text in text_data]
import pickle
pickle.dump(corpus, open('corpus.pkl', 'wb'))
dictionary.save('dictionary.gensim')

# %%
import gensim
NUM_TOPICS = 20
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=15)
ldamodel.save('model5.gensim')
topics = ldamodel.print_topics(num_words=10)
for topic in topics:
    print(topic)
# Out:
# (0, '0.097*"email" + 0.032*"win10" + 0.031*"login" + 0.031*"center" + 0.021*"connection" + 0.021*"server" + 0.021*"authentication" + 0.021*"apply" + 0.021*"working" + 0.021*"software"')
# (1, '0.075*"network" + 0.062*"windows" + 0.043*"unable" + 0.038*"laptop" + 0.038*"performance" + 0.037*"issue" + 0.025*"loaner" + 0.025*"respond" + 0.025*"prompt" + 0.025*"conflict"')
# (2, '0.245*"outlook" + 0.075*"microsoft" + 0.072*"mobileiron" + 0.067*"win10" + 0.015*"connect" + 0.015*"getting" + 0.015*"setup" + 0.015*"update" + 0.010*"install" + 0.008*"change"')
# (3, '0.046*"wireless" + 0.031*"printer" + 0.031*"excel" + 0.031*"instal" + 0.031*"right" + 0.022*"enterprise" + 0.022*"vault" + 0.016*"segment" + 0.016*"compliance" + 0.016*"september"')
# (4, '0.082*"error" + 0.028*"monitor" + 0.028*"unlock" + 0.028*"databas" + 0.027*"project" + 0.014*"device" + 0.014*"follow" + 0.014*"mobileiron" + 0.014*"tomorrow" + 0.014*"endorsement"')
# (5, '0.074*"unable" + 0.073*"access" + 0.037*"internet" + 0.025*"intranet" + 0.025*"microsoft" + 0.025*"outlook" + 0.025*"office" + 0.025*"launch" + 0.025*"recover" + 0.014*"issue"')
# (6, '0.122*"password" + 0.068*"reset" + 0.068*"active" + 0.068*"directory" + 0.041*"delivery" + 0.028*"setup" + 0.017*"email" + 0.014*"delay" + 0.014*"issue" + 0.014*"suite"')
# (7, '0.247*"unable" + 0.083*"connect" + 0.028*"drive" + 0.016*"oracle" + 0.014*"tower" + 0.014*"willis" + 0.014*"showing" + 0.014*"phone" + 0.014*"platform" + 0.014*"insured"')
# (8, '0.043*"windows" + 0.043*"file" + 0.029*"error" + 0.026*"extern" + 0.015*"message" + 0.015*"internal" + 0.015*"folder" + 0.015*"inside" + 0.015*"shortcut" + 0.015*"remote"')
# (9, '0.039*"change" + 0.039*"mobil" + 0.039*"laptop" + 0.039*"upgrade" + 0.026*"julian" + 0.013*"device" + 0.013*"using" + 0.013*"issue" + 0.013*"recent" + 0.013*"request"')
# (10, '0.133*"access" + 0.085*"unable" + 0.067*"cisco" + 0.034*"anyconnect" + 0.033*"win10" + 0.026*"fail" + 0.026*"share" + 0.025*"login" + 0.017*"laptop" + 0.017*"report"')
# (11, '0.185*"skype" + 0.049*"call" + 0.033*"urgent" + 0.017*"30cst" + 0.017*"immediately" + 0.017*"mobile" + 0.017*"hotspot" + 0.017*"velocity" + 0.017*"working" + 0.017*"program"')
# (12, '0.074*"share" + 0.074*"mailbox" + 0.045*"outlook" + 0.030*"studio" + 0.030*"registration" + 0.015*"access" + 0.015*"minit" + 0.015*"every" + 0.015*"later" + 0.015*"proper"')
# (13, '0.031*"unable" + 0.030*"server" + 0.030*"access" + 0.030*"windows" + 0.020*"microsoft" + 0.020*"percentage" + 0.020*"total" + 0.020*"utilization" + 0.020*"request" + 0.020*"wrong"')
# (14, '0.152*"ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x82" + 0.122*"ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83" + 0.025*"active" + 0.025*"directori" + 0.025*"general" + 0.025*"adapter" + 0.013*"question" + 0.013*"leaver" + 0.013*"advice" + 0.013*"dependency"')
# (15, '0.098*"ticket" + 0.065*"mobile" + 0.055*"duplicate" + 0.055*"account" + 0.033*"lock" + 0.031*"ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83" + 0.029*"ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x83ã\x83â£ã\x82â\x83ã\x83â¢ã\x82â\x82ã\x83â£ã\x82â\x82ã\x83â¢ã\x82â\x82" + 0.022*"devic" + 0.022*"logic" + 0.011*"folder"')
# (16, '0.057*"eclipse" + 0.016*"access" + 0.015*"connect" + 0.015*"percentage" + 0.015*"available" + 0.015*"iedbn" + 0.015*"server" + 0.015*"willi" + 0.015*"address" + 0.015*"scope"')
# (17, '0.075*"request" + 0.075*"laptop" + 0.036*"oracle" + 0.025*"september" + 0.025*"environment" + 0.025*"removal" + 0.025*"runtime" + 0.025*"begin" + 0.025*"cyber" + 0.025*"printer"')
# (18, '0.036*"installation" + 0.036*"transfer" + 0.036*"office" + 0.024*"application" + 0.024*"dependency" + 0.024*"employee" + 0.015*"receive" + 0.012*"microsoft" + 0.012*"concern" + 0.012*"nepali"')
# (19, '0.041*"unable" + 0.031*"gbips" + 0.030*"citrix" + 0.016*"amount" + 0.016*"deduction" + 0.016*"delete" + 0.016*"tax" + 0.016*"transaction" + 0.016*"premium" + 0.016*"endors"')
